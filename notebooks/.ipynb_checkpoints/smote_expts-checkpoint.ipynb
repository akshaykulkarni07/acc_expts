# %% [markdown]
# ### Synthetic Minority Oversampling TechniquE (SMOTE)
# This notebook has code that tries to use SMOTE (from `imblearn` library) to improve the performance of the classifier

# %%
# %matplotlib inline
import pandas as pd
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import numpy as np
from tsfresh import extract_features
from tsfresh import extract_relevant_features
import sklearn
import sklearn.naive_bayes
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from sklearn.preprocessing import normalize, minmax_scale
from imblearn.over_sampling import SMOTE
from collections import Counter

# %% [markdown]
# #### Extracting features using `tsfresh`

# %%
data = pd.read_csv('../data/data_only_tsfresh_compatible.csv', names = ['x_acc', 'y_acc', 'z_acc', 'id'])
labels = pd.read_csv('../data/labels_only.csv', names = ['Blocking', 'Dodging', 'Inactive', 'Moving', 'Sprinting'])

# %%
extracted_features = extract_features(data, column_id = "id", column_sort = None, column_kind = None, column_value = None)
print(extracted_features.shape)
# Out:
# Feature Extraction: 100%|██████████| 10/10 [06:10<00:00, 31.40s/it]
# (1068, 2382)

# %%
label_arr = labels.values
label_arr = np.argmax(label_arr, axis = 1)

y_features = np.zeros(extracted_features.shape[0])
for i in range(len(label_arr)) : 
    if i % 150 == 0 : 
        y_features[i // 150] = label_arr[i]
        
# Also converting into Pandas Series for use in extracting relevant features using tsfresh
y = pd.Series(y_features, dtype = int)

# %%
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute

extracted_features = impute(extracted_features)
features_filtered = select_features(extracted_features, y)

# %%
x_features = np.asarray(extracted_features)
print(x_features.shape)
x_features_relevant = np.asarray(features_filtered)
print(x_features_relevant.shape)
# Gives the number of examples per label
print(Counter(y_features))
# Out:
# (1068, 2382)
# (1068, 693)
# Counter({3.0: 411, 2.0: 213, 4.0: 196, 0.0: 129, 1.0: 119})

# %% [markdown]
# #### Shuffle and split into train/test datasets, and normalize the datasets

# %%
x_train, x_test, y_f, y_test = train_test_split(x_features_relevant, y_features)
print(x_train.shape)
print(x_test.shape)
print(y_f.shape)
print(y_test.shape)
x_f = minmax_scale(x_train)
x_test_norm = minmax_scale(x_test)
print(Counter(y_f))
# Out:
# (801, 693)
# (267, 693)
# (801,)
# (267,)
# Counter({3.0: 317, 2.0: 159, 4.0: 136, 0.0: 97, 1.0: 92})

# %% [markdown]
# #### Use Synthetic Minority Oversampling to equalize all classes

# %%
sm = SMOTE(random_state = 33)
x_train_norm, y_train = sm.fit_resample(x_f, y_f)
print(Counter(y_train))
print(y_train.dtype)
y_train = y_train.astype(int)
print(y_train.dtype)
y_test = y_test.astype(int)
# Out:
# Counter({2.0: 317, 3.0: 317, 0.0: 317, 4.0: 317, 1.0: 317})
# float64
# int64

# %%
svm_lin = RandomForestClassifier(n_estimators = 100)
svm_lin.fit(x_train_norm, y_train)
y_pred = svm_lin.predict(x_test_norm)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
y_pred = svm_lin.predict(x_train_norm)
print(confusion_matrix(y_train, y_pred))
print(classification_report(y_train, y_pred))
# Out:
# [[ 2  1  9 12  8]
#  [ 2  7  0 14  4]
#  [ 3  2 22 21  6]
#  [ 8 10 10 49 17]
#  [ 4  8  2 20 26]]
#               precision    recall  f1-score   support
#
#            0       0.11      0.06      0.08        32
#            1       0.25      0.26      0.25        27
#            2       0.51      0.41      0.45        54
#            3       0.42      0.52      0.47        94
#            4       0.43      0.43      0.43        60
#
#     accuracy                           0.40       267
#    macro avg       0.34      0.34      0.34       267
# weighted avg       0.39      0.40      0.39       267
#
# [[317   0   0   0   0]
#  [  0 317   0   0   0]
#  [  1   0 315   1   0]
#  [  0   1   0 315   1]
#  [  0   1   2   1 313]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       317
#            1       0.99      1.00      1.00       317
#            2       0.99      0.99      0.99       317
#            3       0.99      0.99      0.99       317
#            4       1.00      0.99      0.99       317
#
#     accuracy                           0.99      1585
#    macro avg       0.99      0.99      0.99      1585
# weighted avg       0.99      0.99      0.99      1585

# %% [markdown]
# Even using SMOTE did not improve the test accuracy, neither did it significantly reduce the bias due to class unbalance. So, now another option is to repeat the above feature extraction and class balancing on a running window based preprocessing of the data rather than the raw data.
#
# Will do the above in another notebook.

# %% [markdown]
# #### Check if label one-hot encoding is required by `sklearn` (Not required, but it mostly requires labels to be `int` and not `float` or something else)

# %%
# Check if this is necessary
from sklearn.preprocessing import LabelBinarizer
y_train = LabelBinarizer().fit_transform(y_train)
y_test = LabelBinarizer().fit_transform(y_test)

# %%
svm_lin = RandomForestClassifier(n_estimators = 300)
svm_lin.fit(x_train_norm, y_train)
y_pred = svm_lin.predict(x_test_norm)
# print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
y_pred = svm_lin.predict(x_train_norm)
# print(confusion_matrix(y_train, y_pred))
print(classification_report(y_train, y_pred))
# Out:
# /home/akshay/anaconda3/envs/pyt/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/akshay/anaconda3/envs/pyt/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/akshay/anaconda3/envs/pyt/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/akshay/anaconda3/envs/pyt/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        36
#            1       0.00      0.00      0.00        20
#            2       0.00      0.00      0.00        62
#            3       0.00      0.00      0.00        98
#            4       0.50      0.04      0.07        51
#
#    micro avg       0.40      0.01      0.01       267
#    macro avg       0.10      0.01      0.01       267
# weighted avg       0.10      0.01      0.01       267
#  samples avg       0.01      0.01      0.01       267
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       313
#            1       1.00      1.00      1.00       313
#            2       1.00      0.98      0.99       313
#            3       1.00      0.98      0.99       313
#            4       1.00      0.99      0.99       313
#
#    micro avg       1.00      0.99      0.99      1565
#    macro avg       1.00      0.99      0.99      1565
# weighted avg       1.00      0.99      0.99      1565
#  samples avg       0.99      0.99      0.99      1565
# /home/akshay/anaconda3/envs/pyt/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Using alternate examples only

# %%
data = pd.read_csv('../data/alt_data_only_tsfresh_compatible.csv', names = ['x_acc', 'y_acc', 'z_acc', 'id'])
labels = pd.read_csv('../data/alt_labels_only.csv', names = ['Blocking', 'Dodging', 'Inactive', 'Moving', 'Sprinting'])

# %%
extracted_features = extract_features(data, column_id = "id", column_sort = None, column_kind = None, column_value = None)
print(extracted_features.shape)
# Out:
# Feature Extraction: 100%|██████████| 10/10 [03:07<00:00, 15.12s/it]
# (533, 2382)

# %%
label_arr = labels.values
label_arr = np.argmax(label_arr, axis = 1)

y_features = np.zeros(extracted_features.shape[0])
for i in range(len(label_arr)) : 
    if i % 150 == 0 : 
        y_features[i // 150] = label_arr[i]
        
# Also converting into Pandas Series for use in extracting relevant features using tsfresh
y = pd.Series(y_features, dtype = int)

# %%
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute

extracted_features = impute(extracted_features)
features_filtered = select_features(extracted_features, y)
# Out:
# WARNING:tsfresh.utilities.dataframe_functions:The columns ['x_acc__fft_coefficient__coeff_76__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_76__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_76__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_76__attr_"real"'
#  'x_acc__fft_coefficient__coeff_77__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_77__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_77__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_77__attr_"real"'
#  'x_acc__fft_coefficient__coeff_78__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_78__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_78__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_78__attr_"real"'
#  'x_acc__fft_coefficient__coeff_79__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_79__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_79__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_79__attr_"real"'
#  'x_acc__fft_coefficient__coeff_80__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_80__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_80__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_80__attr_"real"'
#  'x_acc__fft_coefficient__coeff_81__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_81__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_81__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_81__attr_"real"'
#  'x_acc__fft_coefficient__coeff_82__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_82__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_82__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_82__attr_"real"'
#  'x_acc__fft_coefficient__coeff_83__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_83__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_83__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_83__attr_"real"'
#  'x_acc__fft_coefficient__coeff_84__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_84__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_84__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_84__attr_"real"'
#  'x_acc__fft_coefficient__coeff_85__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_85__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_85__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_85__attr_"real"'
#  'x_acc__fft_coefficient__coeff_86__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_86__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_86__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_86__attr_"real"'
#  'x_acc__fft_coefficient__coeff_87__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_87__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_87__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_87__attr_"real"'
#  'x_acc__fft_coefficient__coeff_88__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_88__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_88__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_88__attr_"real"'
#  'x_acc__fft_coefficient__coeff_89__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_89__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_89__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_89__attr_"real"'
#  'x_acc__fft_coefficient__coeff_90__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_90__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_90__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_90__attr_"real"'
#  'x_acc__fft_coefficient__coeff_91__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_91__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_91__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_91__attr_"real"'
#  'x_acc__fft_coefficient__coeff_92__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_92__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_92__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_92__attr_"real"'
#  'x_acc__fft_coefficient__coeff_93__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_93__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_93__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_93__attr_"real"'
#  'x_acc__fft_coefficient__coeff_94__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_94__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_94__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_94__attr_"real"'
#  'x_acc__fft_coefficient__coeff_95__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_95__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_95__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_95__attr_"real"'
#  'x_acc__fft_coefficient__coeff_96__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_96__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_96__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_96__attr_"real"'
#  'x_acc__fft_coefficient__coeff_97__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_97__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_97__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_97__attr_"real"'
#  'x_acc__fft_coefficient__coeff_98__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_98__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_98__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_98__attr_"real"'
#  'x_acc__fft_coefficient__coeff_99__attr_"abs"'
#  'x_acc__fft_coefficient__coeff_99__attr_"angle"'
#  'x_acc__fft_coefficient__coeff_99__attr_"imag"'
#  'x_acc__fft_coefficient__coeff_99__attr_"real"'
#  'y_acc__fft_coefficient__coeff_76__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_76__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_76__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_76__attr_"real"'
#  'y_acc__fft_coefficient__coeff_77__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_77__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_77__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_77__attr_"real"'
#  'y_acc__fft_coefficient__coeff_78__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_78__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_78__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_78__attr_"real"'
#  'y_acc__fft_coefficient__coeff_79__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_79__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_79__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_79__attr_"real"'
#  'y_acc__fft_coefficient__coeff_80__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_80__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_80__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_80__attr_"real"'
#  'y_acc__fft_coefficient__coeff_81__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_81__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_81__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_81__attr_"real"'
#  'y_acc__fft_coefficient__coeff_82__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_82__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_82__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_82__attr_"real"'
#  'y_acc__fft_coefficient__coeff_83__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_83__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_83__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_83__attr_"real"'
#  'y_acc__fft_coefficient__coeff_84__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_84__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_84__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_84__attr_"real"'
#  'y_acc__fft_coefficient__coeff_85__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_85__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_85__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_85__attr_"real"'
#  'y_acc__fft_coefficient__coeff_86__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_86__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_86__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_86__attr_"real"'
#  'y_acc__fft_coefficient__coeff_87__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_87__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_87__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_87__attr_"real"'
#  'y_acc__fft_coefficient__coeff_88__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_88__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_88__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_88__attr_"real"'
#  'y_acc__fft_coefficient__coeff_89__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_89__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_89__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_89__attr_"real"'
#  'y_acc__fft_coefficient__coeff_90__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_90__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_90__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_90__attr_"real"'
#  'y_acc__fft_coefficient__coeff_91__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_91__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_91__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_91__attr_"real"'
#  'y_acc__fft_coefficient__coeff_92__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_92__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_92__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_92__attr_"real"'
#  'y_acc__fft_coefficient__coeff_93__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_93__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_93__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_93__attr_"real"'
#  'y_acc__fft_coefficient__coeff_94__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_94__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_94__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_94__attr_"real"'
#  'y_acc__fft_coefficient__coeff_95__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_95__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_95__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_95__attr_"real"'
#  'y_acc__fft_coefficient__coeff_96__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_96__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_96__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_96__attr_"real"'
#  'y_acc__fft_coefficient__coeff_97__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_97__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_97__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_97__attr_"real"'
#  'y_acc__fft_coefficient__coeff_98__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_98__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_98__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_98__attr_"real"'
#  'y_acc__fft_coefficient__coeff_99__attr_"abs"'
#  'y_acc__fft_coefficient__coeff_99__attr_"angle"'
#  'y_acc__fft_coefficient__coeff_99__attr_"imag"'
#  'y_acc__fft_coefficient__coeff_99__attr_"real"'
#  'z_acc__fft_coefficient__coeff_76__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_76__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_76__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_76__attr_"real"'
#  'z_acc__fft_coefficient__coeff_77__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_77__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_77__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_77__attr_"real"'
#  'z_acc__fft_coefficient__coeff_78__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_78__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_78__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_78__attr_"real"'
#  'z_acc__fft_coefficient__coeff_79__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_79__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_79__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_79__attr_"real"'
#  'z_acc__fft_coefficient__coeff_80__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_80__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_80__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_80__attr_"real"'
#  'z_acc__fft_coefficient__coeff_81__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_81__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_81__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_81__attr_"real"'
#  'z_acc__fft_coefficient__coeff_82__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_82__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_82__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_82__attr_"real"'
#  'z_acc__fft_coefficient__coeff_83__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_83__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_83__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_83__attr_"real"'
#  'z_acc__fft_coefficient__coeff_84__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_84__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_84__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_84__attr_"real"'
#  'z_acc__fft_coefficient__coeff_85__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_85__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_85__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_85__attr_"real"'
#  'z_acc__fft_coefficient__coeff_86__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_86__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_86__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_86__attr_"real"'
#  'z_acc__fft_coefficient__coeff_87__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_87__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_87__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_87__attr_"real"'
#  'z_acc__fft_coefficient__coeff_88__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_88__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_88__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_88__attr_"real"'
#  'z_acc__fft_coefficient__coeff_89__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_89__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_89__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_89__attr_"real"'
#  'z_acc__fft_coefficient__coeff_90__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_90__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_90__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_90__attr_"real"'
#  'z_acc__fft_coefficient__coeff_91__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_91__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_91__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_91__attr_"real"'
#  'z_acc__fft_coefficient__coeff_92__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_92__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_92__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_92__attr_"real"'
#  'z_acc__fft_coefficient__coeff_93__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_93__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_93__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_93__attr_"real"'
#  'z_acc__fft_coefficient__coeff_94__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_94__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_94__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_94__attr_"real"'
#  'z_acc__fft_coefficient__coeff_95__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_95__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_95__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_95__attr_"real"'
#  'z_acc__fft_coefficient__coeff_96__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_96__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_96__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_96__attr_"real"'
#  'z_acc__fft_coefficient__coeff_97__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_97__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_97__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_97__attr_"real"'
#  'z_acc__fft_coefficient__coeff_98__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_98__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_98__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_98__attr_"real"'
#  'z_acc__fft_coefficient__coeff_99__attr_"abs"'
#  'z_acc__fft_coefficient__coeff_99__attr_"angle"'
#  'z_acc__fft_coefficient__coeff_99__attr_"imag"'
#  'z_acc__fft_coefficient__coeff_99__attr_"real"'] did not have any finite values. Filling with zeros.
# WARNING:tsfresh.feature_selection.relevance:Infered classification as machine learning task
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_75__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_76__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_76__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_76__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_76__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_77__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_77__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_77__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_77__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_78__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_78__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_78__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_78__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_79__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_79__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_79__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_79__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_80__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_80__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_80__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_80__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_81__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_81__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_81__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_81__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_82__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_82__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_82__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_82__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_83__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_83__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_0__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_83__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_83__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_84__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_84__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_84__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_84__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_85__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_85__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_85__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_86__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_85__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_86__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_86__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_86__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_87__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_87__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_87__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_87__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_88__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_88__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_88__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_88__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_89__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_89__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_89__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_89__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_90__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_90__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_90__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_90__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_91__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_91__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_91__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_91__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_92__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_92__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_92__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_92__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_93__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_93__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_93__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_93__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_94__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_94__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_0__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_94__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_94__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_95__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_95__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_95__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_95__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_96__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_96__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_96__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_96__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_97__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_97__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_97__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_97__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_98__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_98__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_98__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_98__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_99__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_75__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_99__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_99__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_76__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_76__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__fft_coefficient__coeff_99__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__has_duplicate is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_76__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.05 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_76__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_77__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.30000000000000004 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.35000000000000003 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_77__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_77__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_77__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.45 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_78__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_78__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.55 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_78__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.6000000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_78__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.65 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_79__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.7000000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_79__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.75 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_79__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_79__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.8500000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_80__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.9 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_80__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_80__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__large_standard_deviation__r_0.9500000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__length is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_80__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__number_crossing_m__m_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__number_crossing_m__m_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_81__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_81__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__partial_autocorrelation__lag_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_81__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__range_count__max_0__min_1000000000000.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_81__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__range_count__max_1__min_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_82__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__ratio_beyond_r_sigma__r_10 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_82__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__symmetry_looking__r_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_82__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_82__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_83__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_83__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_83__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__symmetry_looking__r_0.15000000000000002 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_83__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__symmetry_looking__r_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_84__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_84__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__symmetry_looking__r_0.25 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_84__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature x_acc__symmetry_looking__r_0.30000000000000004 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_84__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature y_acc__fft_coefficient__coeff_85__attr_"abs" is constant
# ...
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''x_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 2.0} in feature ''z_acc__number_crossing_m__m_-1''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {149.0, 150.0} in feature ''z_acc__range_count__max_1__min_-1''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''z_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''x_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''x_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 2.0} in feature ''z_acc__number_crossing_m__m_-1''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {149.0, 150.0} in feature ''z_acc__range_count__max_1__min_-1''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''z_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''x_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''x_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 2.0} in feature ''z_acc__number_crossing_m__m_-1''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {149.0, 150.0} in feature ''z_acc__range_count__max_1__min_-1''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''z_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''x_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''x_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 2.0} in feature ''z_acc__number_crossing_m__m_-1''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {149.0, 150.0} in feature ''z_acc__range_count__max_1__min_-1''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''z_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''x_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''x_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''x_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''y_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_0__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 180.0} in feature ''z_acc__fft_coefficient__coeff_75__attr_"angle"''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_6''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''y_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {149.0, 150.0} in feature ''z_acc__range_count__max_1__min_-1''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 0.006666666666666667} in feature ''z_acc__ratio_beyond_r_sigma__r_7''.
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] A binary feature should have only values 1 and 0 (incl. True and False). Instead found {0.0, 2.0} in feature ''z_acc__number_crossing_m__m_-1''.

# %%
x_features = np.asarray(extracted_features)
print(x_features.shape)
x_features_relevant = np.asarray(features_filtered)
print(x_features_relevant.shape)
# Gives the number of examples per label
print(Counter(y_features))
# Out:
# (533, 2382)
# (533, 584)
# Counter({3.0: 204, 2.0: 108, 4.0: 95, 0.0: 67, 1.0: 59})

# %% [markdown]
# #### Shuffle and split into train/test datasets, and normalize the datasets

# %%
x_train, x_test, y_f, y_test = train_test_split(x_features_relevant, y_features)
print(x_train.shape)
print(x_test.shape)
print(y_f.shape)
print(y_test.shape)
x_f = minmax_scale(x_train)
x_test_norm = minmax_scale(x_test)
print(Counter(y_f))
# Out:
# (399, 584)
# (134, 584)
# (399,)
# (134,)
# Counter({3.0: 153, 2.0: 88, 4.0: 68, 0.0: 46, 1.0: 44})

# %% [markdown]
# #### Use Synthetic Minority Oversampling to equalize all classes

# %%
sm = SMOTE(random_state = 12)
x_train_norm, y_train = sm.fit_resample(x_f, y_f)
print(Counter(y_train))
print(y_train.dtype)
y_train = y_train.astype(int)
print(y_train.dtype)
y_test = y_test.astype(int)
# Out:
# Counter({4.0: 153, 3.0: 153, 2.0: 153, 0.0: 153, 1.0: 153})
# float64
# int64

# %%
svm_lin = RandomForestClassifier(n_estimators = 100)
svm_lin.fit(x_train_norm, y_train)
y_pred = svm_lin.predict(x_test_norm)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
y_pred = svm_lin.predict(x_train_norm)
print(confusion_matrix(y_train, y_pred))
print(classification_report(y_train, y_pred))
# Out:
# [[ 2  1  3  9  6]
#  [ 0  4  1  9  1]
#  [ 0  1  7  8  4]
#  [ 1  3  3 29 15]
#  [ 0  4  3  7 13]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.10      0.17        21
#            1       0.31      0.27      0.29        15
#            2       0.41      0.35      0.38        20
#            3       0.47      0.57      0.51        51
#            4       0.33      0.48      0.39        27
#
#     accuracy                           0.41       134
#    macro avg       0.44      0.35      0.35       134
# weighted avg       0.45      0.41      0.39       134
#
# [[153   0   0   0   0]
#  [  0 153   0   0   0]
#  [  0   0 153   0   0]
#  [  0   0   0 153   0]
#  [  0   0   0   0 153]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       153
#            1       1.00      1.00      1.00       153
#            2       1.00      1.00      1.00       153
#            3       1.00      1.00      1.00       153
#            4       1.00      1.00      1.00       153
#
#     accuracy                           1.00       765
#    macro avg       1.00      1.00      1.00       765
# weighted avg       1.00      1.00      1.00       765

# %% [markdown]
# Even using alternate examples doesn't improve performance, clearly because the examples remain mislabelled overall. Now the solution would be to re-annotate the data and optionally also collect more data.
